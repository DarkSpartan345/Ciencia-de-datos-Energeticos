# %%
#2018 floor
import pandas as pd
p1_2018=pd.read_csv("2018Floor1.csv")
p1_2019=pd.read_csv("2019Floor1.csv")
p1_2018.head()
# Out:
#                   Date  z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  \
# 0  2018-07-01 00:00:00         12.94        18.56       45.24        0.01
# 1  2018-07-01 00:01:00         12.97        18.55       45.28        0.02
# 2  2018-07-01 00:02:00         12.97        18.55       45.24        0.01
# 3  2018-07-01 00:03:00         12.98        18.58       45.26        0.02
# 4  2018-07-01 00:04:00         13.01        18.60       45.22        0.02
#
#    z2_AC3(kW)  z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  \
# 0        0.01        0.00         13.76        17.64         10.92
# 1        0.01        0.01         13.76        17.21         10.95
# 2        0.01        0.01         13.79        17.18         10.94
# 3        0.01        0.00         13.81        16.64         10.94
# 4        0.01        0.01         13.83        15.69         10.97
#
#    z3_Plug(kW)  z4_Light(kW)
# 0         0.89         35.76
# 1         0.87         35.81
# 2         0.86         35.78
# 3         0.85         35.83
# 4         0.85         35.86

# %%
P1= pd.concat([p1_2018, p1_2019], ignore_index=True)
Z1=P1[['Date','z1_Light(kW)','z1_Plug(kW)']]
Z3=P1[['Date','z3_Light(kW)','z3_Plug(kW)']]
Z4=P1[['Date','z4_Light(kW)']]
Z2=P1[['Date','z2_AC1(kW)','z2_AC2(kW)','z2_AC3(kW)','z2_AC4(kW)']]

Z1.head(86000)
# Out:
#                       Date  z1_Light(kW)  z1_Plug(kW)
# 0      2018-07-01 00:00:00         12.94        18.56
# 1      2018-07-01 00:01:00         12.97        18.55
# 2      2018-07-01 00:02:00         12.97        18.55
# 3      2018-07-01 00:03:00         12.98        18.58
# 4      2018-07-01 00:04:00         13.01        18.60
# ...                    ...           ...          ...
# 85995  2018-08-29 17:15:00         11.89         1.18
# 85996  2018-08-29 17:16:00         14.09         1.41
# 85997  2018-08-29 17:17:00         11.68         1.16
# 85998  2018-08-29 17:18:00         14.08         1.49
# 85999  2018-08-29 17:19:00         11.71         1.24
#
# [86000 rows x 3 columns]

# %%
def MeanHour(Z1):
    # Asegúrate de que 'Date' es datetime
    Z=Z1
    Z['Date'] = pd.to_datetime(Z['Date'])
    
    # Extraer la hora
    Z['hour'] = Z['Date'].dt.hour
    
    # Agrupar por hora y calcular el promedio
    hourly_avg = Z.groupby('hour').mean()
    
    # Mostrar resultado
    return(hourly_avg)
def MeanDayofWeek(Z1):
     # Asegúrate de que 'Date' es datetime
    Z1['Date'] = pd.to_datetime(Z1['Date'])
    
    # Extraer la hora
    Z1['dayofweek'] = Z1['Date'].dt.dayofweek
    
    # Agrupar por hora y calcular el promedio
    dayofweek_avg = Z1.groupby('dayofweek').mean()
    
    # Mostrar resultado
    return(dayofweek_avg)
def MeanMouth(Z1):
     # Asegúrate de que 'Date' es datetime
    Z1['Date'] = pd.to_datetime(Z1['Date'])
    
    # Extraer la hora
    Z1['month'] = Z1['Date'].dt.month
    
    # Agrupar por hora y calcular el promedio
    month_avg = Z1.groupby('month').mean()
    
    # Mostrar resultado
    return(month_avg)

# %%
MeanZ1=[MeanHour(Z1),MeanDayofWeek(Z1),MeanMouth(Z1)]
MeanZ2=[MeanHour(Z2),MeanDayofWeek(Z1),MeanMouth(Z2)]
MeanZ3=[MeanHour(Z3),MeanDayofWeek(Z3),MeanMouth(Z3)]
MeanZ4=[MeanHour(Z4),MeanDayofWeek(Z4),MeanMouth(Z4)]
# Out:
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['hour'] = Z1['Date'].dt.hour
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['dayofweek'] = Z1['Date'].dt.dayofweek
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['month'] = Z1['Date'].dt.month
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['hour'] = Z1['Date'].dt.hour
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['dayofweek'] = Z1['Date'].dt.dayofweek
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['month'] = Z1['Date'].dt.month
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['hour'] = Z1['Date'].dt.hour
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['dayofweek'] = Z1['Date'].dt.dayofweek
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['month'] = Z1['Date'].dt.month
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['hour'] = Z1['Date'].dt.hour
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['dayofweek'] = Z1['Date'].dt.dayofweek
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['Date'] = pd.to_datetime(Z1['Date'])
# C:\Users\DarkSpartan345\AppData\Local\Temp\ipykernel_14896\1233287432.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Z1['month'] = Z1['Date'].dt.month

# %%
import matplotlib.pyplot as plt

hourly_avg['z1_Plug(kW)'].plot(figsize=(10,6))
plt.title('Consumo promedio por hora del día')
plt.xlabel('Hora del día')
plt.ylabel('Consumo promedio (kW)')
plt.grid(True)
plt.xticks(range(0,24))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 hourly_avg['z1_Plug(kW)'].plot(figsize=(10,6))
#       4 plt.title('Consumo promedio por hora del día')
#       5 plt.xlabel('Hora del día')
#
# NameError: name 'hourly_avg' is not defined
