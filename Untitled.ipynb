# %%
#2018 floor
import pandas as pd
p1_2018=pd.read_csv("2018Floor1.csv")
p1_2019=pd.read_csv("2019Floor1.csv")
p1_2018.head()
# Out:
#                   Date  z1_Light(kW)  z1_Plug(kW)  z2_AC1(kW)  z2_AC2(kW)  \
# 0  2018-07-01 00:00:00         12.94        18.56       45.24        0.01
# 1  2018-07-01 00:01:00         12.97        18.55       45.28        0.02
# 2  2018-07-01 00:02:00         12.97        18.55       45.24        0.01
# 3  2018-07-01 00:03:00         12.98        18.58       45.26        0.02
# 4  2018-07-01 00:04:00         13.01        18.60       45.22        0.02
#
#    z2_AC3(kW)  z2_AC4(kW)  z2_Light(kW)  z2_Plug(kW)  z3_Light(kW)  \
# 0        0.01        0.00         13.76        17.64         10.92
# 1        0.01        0.01         13.76        17.21         10.95
# 2        0.01        0.01         13.79        17.18         10.94
# 3        0.01        0.00         13.81        16.64         10.94
# 4        0.01        0.01         13.83        15.69         10.97
#
#    z3_Plug(kW)  z4_Light(kW)
# 0         0.89         35.76
# 1         0.87         35.81
# ...

# %%
P1= pd.concat([p1_2018, p1_2019], ignore_index=True)
column_name_map = {
    'z1_Light(kW)': 'Zona 1 - Iluminación (kW)',
    'z1_Plug(kW)': 'Zona 1 - Enchufes (kW)',
    'z2_AC1(kW)': 'Zona 2 - Aire Acondicionado 1 (kW)',
    'z2_AC2(kW)': 'Zona 2 - Aire Acondicionado 2 (kW)',
    'z2_AC3(kW)': 'Zona 2 - Aire Acondicionado 3 (kW)',
    'z2_AC4(kW)': 'Zona 2 - Aire Acondicionado 4 (kW)',
    'z2_Light(kW)': 'Zona 2 - Iluminación (kW)',
    'z2_Plug(kW)': 'Zona 2 - Enchufes (kW)',
    'z3_Light(kW)': 'Zona 3 - Iluminación (kW)',
    'z3_Plug(kW)': 'Zona 3 - Enchufes (kW)',
    'z4_Light(kW)': 'Zona 4 - Iluminación (kW)'
}
P1 = P1.rename(columns=column_name_map)
Z1=P1[['Date','Zona 1 - Iluminación (kW)','Zona 1 - Enchufes (kW)']]
Z3=P1[['Date','Zona 3 - Iluminación (kW)','Zona 3 - Enchufes (kW)']]
Z4=P1[['Date','Zona 4 - Iluminación (kW)']]
Z2=P1[['Date','Zona 2 - Aire Acondicionado 1 (kW)','Zona 2 - Aire Acondicionado 2 (kW)','Zona 2 - Aire Acondicionado 3 (kW)','Zona 2 - Aire Acondicionado 4 (kW)','Zona 2 - Iluminación (kW)','Zona 2 - Enchufes (kW)']]

Z1.head(86000)
# Out:
#                       Date  Zona 1 - Iluminación (kW)  Zona 1 - Enchufes (kW)
# 0      2018-07-01 00:00:00                      12.94                   18.56
# 1      2018-07-01 00:01:00                      12.97                   18.55
# 2      2018-07-01 00:02:00                      12.97                   18.55
# 3      2018-07-01 00:03:00                      12.98                   18.58
# 4      2018-07-01 00:04:00                      13.01                   18.60
# ...                    ...                        ...                     ...
# 85995  2018-08-29 17:15:00                      11.89                    1.18
# 85996  2018-08-29 17:16:00                      14.09                    1.41
# 85997  2018-08-29 17:17:00                      11.68                    1.16
# 85998  2018-08-29 17:18:00                      14.08                    1.49
# 85999  2018-08-29 17:19:00                      11.71                    1.24
#
# [86000 rows x 3 columns]

# %%
def MeanHour(Z1):
    # Asegúrate de que 'Date' es datetime
    Z=Z1.copy()
    Z['Date'] = pd.to_datetime(Z['Date'])
    
    # Extraer la hora
    Z['hour'] = Z['Date'].dt.hour
    
    # Agrupar por hora y calcular el promedio
    hourly_avg = Z.groupby('hour').mean()
    
    # Mostrar resultado
    return(hourly_avg)
def MeanDayofWeek(Z1):
     # Asegúrate de que 'Date' es datetime
    Z=Z1.copy()
    Z['Date'] = pd.to_datetime(Z['Date'])
    
    # Extraer la hora
    Z['dayofweek'] = Z['Date'].dt.dayofweek
    
    # Agrupar por hora y calcular el promedio
    dayofweek_avg = Z.groupby('dayofweek').mean()
    
    # Mostrar resultado
    return(dayofweek_avg)
def MeanMouth(Z1):
     # Asegúrate de que 'Date' es datetime
    Z=Z1.copy()
    Z['Date'] = pd.to_datetime(Z['Date'])
    
    # Extraer la hora
    Z['month'] = Z['Date'].dt.month
    
    # Agrupar por hora y calcular el promedio
    month_avg = Z.groupby('month').mean()
    
    # Mostrar resultado
    return(month_avg)

# %%
MeanZ1=[MeanHour(Z1),MeanDayofWeek(Z1),MeanMouth(Z1)]
MeanZ2=[MeanHour(Z2),MeanDayofWeek(Z1),MeanMouth(Z2)]
MeanZ3=[MeanHour(Z3),MeanDayofWeek(Z3),MeanMouth(Z3)]
MeanZ4=[MeanHour(Z4),MeanDayofWeek(Z4),MeanMouth(Z4)]

# %%
import matplotlib.pyplot as plt
def Plotting(Z,title,xlabel,ylabel,xticks,Xlabels):
    for name in Z.columns[1::]:
        Z[name].plot(figsize=(13,6))
        plt.title(f'{title} {name}')
        plt.xlabel(xlabel)
        plt.ylabel(ylabel)
        plt.grid(True)
        plt.xticks(ticks=xticks,labels=Xlabels)
        plt.show()
def MainPlotting(Z):
    
    MeanHourZ=Z[0]
    MeanDayofWeekZ=Z[1]
    MeanMouthZ=Z[2]
    dias = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']
    meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio',
         'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Noviembre', 'Diciembre']
    Plotting(MeanHourZ,'Consumo promedio por hora del día de:','Hora del día','Consumo promedio (kW)',range(0,24),range(0,24))
    Plotting(MeanDayofWeekZ,'Consumo promedio por día de la semana de:','dia de la semana','Consumo promedio (kW)',range(0,7),dias)
    Plotting(MeanMouthZ,'Consumo promedio por mes del año de:','mes del año','Consumo promedio (kW)',range(1,13),meses)

# %%
MainPlotting(MeanZ1)

# %%
MainPlotting(MeanZ2)

# %%
MainPlotting(MeanZ3)

# %%
MainPlotting(MeanZ4)
